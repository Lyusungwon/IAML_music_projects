# %%
import os
import tensorflow as tf
import pandas as pd
import numpy as np
import pickle
import math
import librosa
import matplotlib.pyplot as plt
from tensorflow.python.platform import gfile
from time import strftime, localtime, time

# %%
# Feature Extraction function

def get_features(tids):
    mfcc_list = []
    try:
        for n, tid in enumerate(tids):
            tid, mfcc= compute_features(tid)
            mfcc_list.append(mfcc)
            print("Extracted features audio track", n)
    except Exception as e:
        print('{}: {}'.format(tid, repr(e)))

    return np.array(mfcc_list)

def compute_features(tid):
    threshold = 1278900
    try:
        filepath = get_audio_path('music/music_training', tid)
        x, sr = librosa.load(filepath, sr=None, mono=True, duration=29.0)  # kaiser_fast
        x = x.tolist()
        if(len(x) < threshold):
            raise ValueError('song length is shorter than threshold')
        else:
            x = x[:int(1278900)]#131000
        x = np.array(x)
        stft = np.abs(librosa.stft(x, n_fft=2048, hop_length=512))
        mel = librosa.feature.melspectrogram(sr=sr, S=stft ** 2)
        mfcc = librosa.feature.mfcc(S=librosa.power_to_db(mel), n_mfcc=20)

    except Exception as e:
        print('{}: {}'.format(tid, repr(e)))
        return tid, 0

    return tid, mfcc.tolist()

def get_audio_path(audio_dir, track_id):
    tid_str = '{:06d}'.format(track_id)
    return os.path.join(audio_dir, tid_str[:3], tid_str + '.mp3')

# %%
#Extract Training Sets

metadata_path = 'dataset/track_metadata.csv'
label_column_name = 'track_genre_top'
is_train_mode = True
label_dict = {'Electronic': 6,
 'Experimental': 4,
 'Folk': 7,
 'Hip-Hop': 2,
 'Instrumental': 3,
 'International': 1,
 'Pop': 5,
 'Rock': 0}

metadata_df = pd.read_csv(metadata_path)
if is_train_mode:
    metadata_df = metadata_df[metadata_df['set_split'] == 'training']
else:
    metadata_df = metadata_df[metadata_df['set_split'] == 'validation']
track_ids = np.array(metadata_df['track_id'])
tn = len(track_ids)
mfcc = get_features(track_ids)

########IMPORTANT############ Modify Training Sets

split = 10
n = mfcc.shape[0]
h = mfcc.shape[1]
w = mfcc.shape[2]//split
mfcce = np.zeros((n*split, h, w))
for i in range(split):
    mfcce[i*n:(i+1)*n, :, :w] = mfcc[:,:,i*w:(i+1)*w]
label_array = np.zeros((metadata_df.shape[0]*split, len(label_dict)))
labels = metadata_df[label_column_name].values
for j in range(split):
    for i, label in enumerate(labels):
        label_pos = label_dict.get(label)
        label_array[j*tn + i, label_pos] = 1
ys = label_array.copy()
# Out:
# Extracted features audio track 0
# Extracted features audio track 1
# Extracted features audio track 2
# Extracted features audio track 3
# Extracted features audio track 4
# Extracted features audio track 5
# Extracted features audio track 6
# Extracted features audio track 7
# Extracted features audio track 8
# Extracted features audio track 9
# Extracted features audio track 10
# Extracted features audio track 11
# Extracted features audio track 12
# Extracted features audio track 13
# Extracted features audio track 14
# Extracted features audio track 15
# Extracted features audio track 16
# Extracted features audio track 17
# Extracted features audio track 18
# Extracted features audio track 19
# Extracted features audio track 20
# Extracted features audio track 21
# Extracted features audio track 22
# Extracted features audio track 23
# Extracted features audio track 24
# Extracted features audio track 25
# Extracted features audio track 26
# Extracted features audio track 27
# Extracted features audio track 28
# Extracted features audio track 29
# Extracted features audio track 30
# Extracted features audio track 31
# Extracted features audio track 32
# Extracted features audio track 33
# Extracted features audio track 34
# Extracted features audio track 35
# Extracted features audio track 36
# Extracted features audio track 37
# Extracted features audio track 38
# Extracted features audio track 39
# Extracted features audio track 40
# Extracted features audio track 41
# Extracted features audio track 42
# Extracted features audio track 43
# Extracted features audio track 44
# Extracted features audio track 45
# Extracted features audio track 46
# Extracted features audio track 47
# Extracted features audio track 48
# Extracted features audio track 49
# Extracted features audio track 50
# Extracted features audio track 51
# Extracted features audio track 52
# Extracted features audio track 53
# Extracted features audio track 54
# Extracted features audio track 55
# Extracted features audio track 56
# Extracted features audio track 57
# Extracted features audio track 58
# Extracted features audio track 59
# Extracted features audio track 60
# Extracted features audio track 61
# Extracted features audio track 62
# Extracted features audio track 63
# Extracted features audio track 64
# Extracted features audio track 65
# Extracted features audio track 66
# Extracted features audio track 67
# Extracted features audio track 68
# Extracted features audio track 69
# Extracted features audio track 70
# Extracted features audio track 71
# Extracted features audio track 72
# Extracted features audio track 73
# Extracted features audio track 74
# Extracted features audio track 75
# Extracted features audio track 76
# Extracted features audio track 77
# Extracted features audio track 78
# Extracted features audio track 79
# Extracted features audio track 80
# Extracted features audio track 81
# Extracted features audio track 82
# Extracted features audio track 83
# Extracted features audio track 84
# Extracted features audio track 85
# Extracted features audio track 86
# Extracted features audio track 87
# Extracted features audio track 88
# Extracted features audio track 89
# Extracted features audio track 90
# Extracted features audio track 91
# Extracted features audio track 92
# Extracted features audio track 93
# Extracted features audio track 94
# Extracted features audio track 95
# Extracted features audio track 96
# Extracted features audio track 97
# Extracted features audio track 98
# Extracted features audio track 99
# Extracted features audio track 100
# Extracted features audio track 101
# Extracted features audio track 102
# Extracted features audio track 103
# Extracted features audio track 104
# Extracted features audio track 105
# Extracted features audio track 106
# Extracted features audio track 107
# Extracted features audio track 108
# Extracted features audio track 109
# Extracted features audio track 110
# Extracted features audio track 111
# Extracted features audio track 112
# Extracted features audio track 113
# Extracted features audio track 114
# Extracted features audio track 115
# Extracted features audio track 116
# Extracted features audio track 117
# Extracted features audio track 118
# Extracted features audio track 119
# Extracted features audio track 120
# Extracted features audio track 121
# Extracted features audio track 122
# Extracted features audio track 123
# Extracted features audio track 124
# Extracted features audio track 125
# Extracted features audio track 126
# Extracted features audio track 127
# Extracted features audio track 128
# Extracted features audio track 129
# Extracted features audio track 130
# Extracted features audio track 131
# Extracted features audio track 132
# Extracted features audio track 133
# Extracted features audio track 134
# Extracted features audio track 135
# Extracted features audio track 136
# Extracted features audio track 137
# Extracted features audio track 138
# Extracted features audio track 139
# Extracted features audio track 140
# Extracted features audio track 141
# Extracted features audio track 142
# Extracted features audio track 143
# Extracted features audio track 144
# Extracted features audio track 145
# Extracted features audio track 146
# Extracted features audio track 147
# Extracted features audio track 148
# Extracted features audio track 149
# Extracted features audio track 150
# Extracted features audio track 151
# Extracted features audio track 152
# Extracted features audio track 153
# Extracted features audio track 154
# Extracted features audio track 155
# Extracted features audio track 156
# Extracted features audio track 157
# Extracted features audio track 158
# Extracted features audio track 159
# Extracted features audio track 160
# Extracted features audio track 161
# Extracted features audio track 162
# Extracted features audio track 163
# Extracted features audio track 164
# Extracted features audio track 165
# Extracted features audio track 166
# Extracted features audio track 167
# Extracted features audio track 168
# Extracted features audio track 169
# Extracted features audio track 170
# Extracted features audio track 171
# Extracted features audio track 172
# Extracted features audio track 173
# Extracted features audio track 174
# Extracted features audio track 175
# Extracted features audio track 176
# Extracted features audio track 177
# Extracted features audio track 178
# Extracted features audio track 179
# Extracted features audio track 180
# Extracted features audio track 181
# Extracted features audio track 182
# Extracted features audio track 183
# Extracted features audio track 184
# Extracted features audio track 185
# Extracted features audio track 186
# Extracted features audio track 187
# Extracted features audio track 188
# Extracted features audio track 189
# Extracted features audio track 190
# Extracted features audio track 191
# Extracted features audio track 192
# Extracted features audio track 193
# Extracted features audio track 194
# Extracted features audio track 195
# Extracted features audio track 196
# Extracted features audio track 197
# Extracted features audio track 198
# Extracted features audio track 199

# %%
#Save as pkl
with open('mfcce.pkl', 'wb') as mfccf:
    pickle.dump(mfcce, mfccf, protocol=pickle.HIGHEST_PROTOCOL)
with open('ye.pkl', 'wb') as yf:
    pickle.dump(ys, yf, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# Load Training Sets

class MacOSFile(object):
    def __init__(self, f):
        self.f = f

    def __getattr__(self, item):
        return getattr(self.f, item)

    def read(self, n):
        if n >= (1 << 31):
            buffer = bytearray(n)
            pos = 0
            while pos < n:
                size = min(n - pos, 1 << 31 - 1)
                chunk = self.f.read(size)
                buffer[pos:pos + size] = chunk
                pos += size
            return buffer
        return self.f.read(n)

with open("mfcce.pkl", 'rb') as mfccf:
	Xd = pickle.load(MacOSFile(mfccf))
with open("ye.pkl", 'rb') as yf:
	yd = pickle.load(yf)

# %%
###############Extract Validation/Test Sets###############

is_train_mode = False

metadata_df = pd.read_csv(metadata_path)
if is_train_mode:
    metadata_df = metadata_df[metadata_df['set_split'] == 'training']
else:
    metadata_df = metadata_df[metadata_df['set_split'] == 'validation'] ######################## Modify here to insert test index
track_ids_val = np.array(metadata_df['track_id'])
vn = len(track_ids_val)
mfcc_val = get_features(track_ids_val)

########IMPORTANT############ Modify Training Sets

split = 10
n = mfcc_val.shape[0]
h = mfcc_val.shape[1]
w = mfcc_val.shape[2]//split
mfcce_val = np.zeros((n*split, h, w))
for i in range(split):
    mfcce_val[i*n:(i+1)*n, :, :w] = mfcc_val[:,:,i*w:(i+1)*w]
label_array_val = np.zeros((metadata_df.shape[0]*split, len(label_dict)))
labels = metadata_df[label_column_name].values
for j in range(split):
    for i, label in enumerate(labels):
        label_pos = label_dict.get(label)
        label_array_val[j*vn + i, label_pos] = 1
ys_val = label_array_val.copy()
# Out:
# Extracted features audio track 0
# Extracted features audio track 1
# Extracted features audio track 2
# Extracted features audio track 3
# Extracted features audio track 4
# Extracted features audio track 5
# Extracted features audio track 6
# Extracted features audio track 7
# Extracted features audio track 8
# Extracted features audio track 9
# Extracted features audio track 10
# Extracted features audio track 11
# Extracted features audio track 12
# Extracted features audio track 13
# Extracted features audio track 14
# Extracted features audio track 15
# Extracted features audio track 16
# Extracted features audio track 17
# Extracted features audio track 18
# Extracted features audio track 19
# Extracted features audio track 20
# Extracted features audio track 21
# Extracted features audio track 22
# Extracted features audio track 23
# Extracted features audio track 24
# Extracted features audio track 25
# Extracted features audio track 26
# Extracted features audio track 27
# Extracted features audio track 28
# Extracted features audio track 29
# Extracted features audio track 30
# Extracted features audio track 31
# Extracted features audio track 32
# Extracted features audio track 33
# Extracted features audio track 34
# Extracted features audio track 35
# Extracted features audio track 36
# Extracted features audio track 37
# Extracted features audio track 38
# Extracted features audio track 39
# Extracted features audio track 40
# Extracted features audio track 41
# Extracted features audio track 42
# Extracted features audio track 43
# Extracted features audio track 44
# Extracted features audio track 45
# Extracted features audio track 46
# Extracted features audio track 47
# Extracted features audio track 48
# Extracted features audio track 49
# Extracted features audio track 50
# Extracted features audio track 51
# Extracted features audio track 52
# Extracted features audio track 53
# Extracted features audio track 54
# Extracted features audio track 55
# Extracted features audio track 56
# Extracted features audio track 57
# Extracted features audio track 58
# Extracted features audio track 59
# Extracted features audio track 60
# Extracted features audio track 61
# Extracted features audio track 62
# Extracted features audio track 63
# Extracted features audio track 64
# Extracted features audio track 65
# Extracted features audio track 66
# Extracted features audio track 67
# Extracted features audio track 68
# Extracted features audio track 69
# Extracted features audio track 70
# Extracted features audio track 71
# Extracted features audio track 72
# Extracted features audio track 73
# Extracted features audio track 74
# Extracted features audio track 75
# Extracted features audio track 76
# Extracted features audio track 77
# Extracted features audio track 78
# Extracted features audio track 79
# Extracted features audio track 80
# Extracted features audio track 81
# Extracted features audio track 82
# Extracted features audio track 83
# Extracted features audio track 84
# Extracted features audio track 85
# Extracted features audio track 86
# Extracted features audio track 87
# Extracted features audio track 88
# Extracted features audio track 89
# Extracted features audio track 90
# Extracted features audio track 91
# Extracted features audio track 92
# Extracted features audio track 93
# Extracted features audio track 94
# Extracted features audio track 95
# Extracted features audio track 96
# Extracted features audio track 97
# Extracted features audio track 98
# Extracted features audio track 99
# Extracted features audio track 100
# Extracted features audio track 101
# Extracted features audio track 102
# Extracted features audio track 103
# Extracted features audio track 104
# Extracted features audio track 105
# Extracted features audio track 106
# Extracted features audio track 107
# Extracted features audio track 108
# Extracted features audio track 109
# Extracted features audio track 110
# Extracted features audio track 111
# Extracted features audio track 112
# Extracted features audio track 113
# Extracted features audio track 114
# Extracted features audio track 115
# Extracted features audio track 116
# Extracted features audio track 117
# Extracted features audio track 118
# Extracted features audio track 119
# Extracted features audio track 120
# Extracted features audio track 121
# Extracted features audio track 122
# Extracted features audio track 123
# Extracted features audio track 124
# Extracted features audio track 125
# Extracted features audio track 126
# Extracted features audio track 127
# Extracted features audio track 128
# Extracted features audio track 129
# Extracted features audio track 130
# Extracted features audio track 131
# Extracted features audio track 132
# Extracted features audio track 133
# Extracted features audio track 134
# Extracted features audio track 135
# Extracted features audio track 136
# Extracted features audio track 137
# Extracted features audio track 138
# Extracted features audio track 139
# Extracted features audio track 140
# Extracted features audio track 141
# Extracted features audio track 142
# Extracted features audio track 143
# Extracted features audio track 144
# Extracted features audio track 145
# Extracted features audio track 146
# Extracted features audio track 147
# Extracted features audio track 148
# Extracted features audio track 149
# Extracted features audio track 150
# Extracted features audio track 151
# Extracted features audio track 152
# Extracted features audio track 153
# Extracted features audio track 154
# Extracted features audio track 155
# Extracted features audio track 156
# Extracted features audio track 157
# Extracted features audio track 158
# Extracted features audio track 159
# Extracted features audio track 160
# Extracted features audio track 161
# Extracted features audio track 162
# Extracted features audio track 163
# Extracted features audio track 164
# Extracted features audio track 165
# Extracted features audio track 166
# Extracted features audio track 167
# Extracted features audio track 168
# Extracted features audio track 169
# Extracted features audio track 170
# Extracted features audio track 171
# Extracted features audio track 172
# Extracted features audio track 173
# Extracted features audio track 174
# Extracted features audio track 175
# Extracted features audio track 176
# Extracted features audio track 177
# Extracted features audio track 178
# Extracted features audio track 179
# Extracted features audio track 180
# Extracted features audio track 181
# Extracted features audio track 182
# Extracted features audio track 183
# Extracted features audio track 184
# Extracted features audio track 185
# Extracted features audio track 186
# Extracted features audio track 187
# Extracted features audio track 188
# Extracted features audio track 189
# Extracted features audio track 190
# Extracted features audio track 191
# Extracted features audio track 192
# Extracted features audio track 193
# Extracted features audio track 194
# Extracted features audio track 195
# Extracted features audio track 196
# Extracted features audio track 197
# Extracted features audio track 198
# Extracted features audio track 199
# Extracted features audio track 200
# Extracted features audio track 201
# Extracted features audio track 202
# Extracted features audio track 203
# Extracted features audio track 204
# Extracted features audio track 205
# Extracted features audio track 206
# Extracted features audio track 207
# Extracted features audio track 208
# Extracted features audio track 209
# Extracted features audio track 210
# Extracted features audio track 211
# Extracted features audio track 212
# Extracted features audio track 213
# Extracted features audio track 214
# Extracted features audio track 215
# Extracted features audio track 216
# Extracted features audio track 217
# Extracted features audio track 218
# Extracted features audio track 219
# Extracted features audio track 220
# Extracted features audio track 221
# Extracted features audio track 222
# Extracted features audio track 223
# Extracted features audio track 224
# Extracted features audio track 225
# Extracted features audio track 226
# Extracted features audio track 227
# Extracted features audio track 228
# Extracted features audio track 229
# Extracted features audio track 230
# Extracted features audio track 231
# Extracted features audio track 232
# Extracted features audio track 233
# Extracted features audio track 234
# Extracted features audio track 235
# Extracted features audio track 236
# Extracted features audio track 237
# Extracted features audio track 238
# Extracted features audio track 239
# Extracted features audio track 240
# Extracted features audio track 241
# Extracted features audio track 242
# Extracted features audio track 243
# Extracted features audio track 244
# Extracted features audio track 245
# Extracted features audio track 246
# Extracted features audio track 247
# Extracted features audio track 248
# Extracted features audio track 249
# Extracted features audio track 250
# Extracted features audio track 251
# Extracted features audio track 252
# Extracted features audio track 253
# Extracted features audio track 254
# Extracted features audio track 255
# Extracted features audio track 256
# Extracted features audio track 257
# Extracted features audio track 258
# Extracted features audio track 259
# Extracted features audio track 260
# Extracted features audio track 261
# Extracted features audio track 262
# Extracted features audio track 263
# Extracted features audio track 264
# Extracted features audio track 265
# Extracted features audio track 266
# Extracted features audio track 267
# Extracted features audio track 268
# Extracted features audio track 269
# Extracted features audio track 270
# Extracted features audio track 271
# Extracted features audio track 272
# Extracted features audio track 273
# Extracted features audio track 274
# Extracted features audio track 275
# Extracted features audio track 276
# Extracted features audio track 277
# Extracted features audio track 278
# Extracted features audio track 279
# Extracted features audio track 280
# Extracted features audio track 281
# Extracted features audio track 282
# Extracted features audio track 283
# Extracted features audio track 284
# Extracted features audio track 285
# Extracted features audio track 286
# Extracted features audio track 287
# Extracted features audio track 288
# Extracted features audio track 289
# Extracted features audio track 290
# Extracted features audio track 291
# Extracted features audio track 292
# Extracted features audio track 293
# Extracted features audio track 294
# Extracted features audio track 295
# Extracted features audio track 296
# Extracted features audio track 297
# Extracted features audio track 298
# Extracted features audio track 299
# Extracted features audio track 300
# Extracted features audio track 301
# Extracted features audio track 302
# Extracted features audio track 303
# Extracted features audio track 304
# Extracted features audio track 305
# Extracted features audio track 306
# Extracted features audio track 307
# Extracted features audio track 308
# Extracted features audio track 309
# Extracted features audio track 310
# Extracted features audio track 311
# Extracted features audio track 312
# Extracted features audio track 313
# Extracted features audio track 314
# Extracted features audio track 315
# Extracted features audio track 316
# Extracted features audio track 317
# Extracted features audio track 318
# Extracted features audio track 319
# Extracted features audio track 320
# Extracted features audio track 321
# Extracted features audio track 322
# Extracted features audio track 323
# Extracted features audio track 324
# Extracted features audio track 325
# Extracted features audio track 326
# Extracted features audio track 327
# Extracted features audio track 328
# Extracted features audio track 329
# Extracted features audio track 330
# Extracted features audio track 331
# Extracted features audio track 332
# Extracted features audio track 333
# Extracted features audio track 334
# Extracted features audio track 335
# Extracted features audio track 336
# Extracted features audio track 337
# Extracted features audio track 338
# Extracted features audio track 339
# Extracted features audio track 340
# Extracted features audio track 341
# Extracted features audio track 342
# Extracted features audio track 343
# Extracted features audio track 344
# Extracted features audio track 345
# Extracted features audio track 346
# Extracted features audio track 347
# Extracted features audio track 348
# Extracted features audio track 349
# Extracted features audio track 350
# Extracted features audio track 351
# Extracted features audio track 352
# Extracted features audio track 353
# Extracted features audio track 354
# Extracted features audio track 355
# Extracted features audio track 356
# Extracted features audio track 357
# Extracted features audio track 358
# Extracted features audio track 359
# Extracted features audio track 360
# Extracted features audio track 361
# Extracted features audio track 362
# Extracted features audio track 363
# Extracted features audio track 364
# Extracted features audio track 365
# Extracted features audio track 366
# Extracted features audio track 367
# Extracted features audio track 368
# Extracted features audio track 369
# Extracted features audio track 370
# Extracted features audio track 371
# Extracted features audio track 372
# Extracted features audio track 373
# Extracted features audio track 374
# Extracted features audio track 375
# Extracted features audio track 376
# Extracted features audio track 377
# Extracted features audio track 378
# Extracted features audio track 379
# Extracted features audio track 380
# Extracted features audio track 381
# Extracted features audio track 382
# Extracted features audio track 383
# Extracted features audio track 384
# Extracted features audio track 385
# Extracted features audio track 386
# Extracted features audio track 387
# Extracted features audio track 388
# Extracted features audio track 389
# Extracted features audio track 390
# Extracted features audio track 391
# Extracted features audio track 392
# Extracted features audio track 393
# Extracted features audio track 394
# Extracted features audio track 395
# Extracted features audio track 396
# Extracted features audio track 397
# Extracted features audio track 398
# Extracted features audio track 399
# Extracted features audio track 400
# Extracted features audio track 401
# Extracted features audio track 402
# Extracted features audio track 403
# Extracted features audio track 404
# Extracted features audio track 405
# Extracted features audio track 406
# Extracted features audio track 407
# Extracted features audio track 408
# Extracted features audio track 409
# Extracted features audio track 410
# Extracted features audio track 411
# Extracted features audio track 412
# Extracted features audio track 413
# Extracted features audio track 414
# Extracted features audio track 415
# Extracted features audio track 416
# Extracted features audio track 417
# Extracted features audio track 418
# Extracted features audio track 419
# Extracted features audio track 420
# Extracted features audio track 421
# Extracted features audio track 422
# Extracted features audio track 423
# Extracted features audio track 424
# Extracted features audio track 425
# Extracted features audio track 426
# Extracted features audio track 427
# Extracted features audio track 428
# Extracted features audio track 429
# Extracted features audio track 430
# Extracted features audio track 431
# Extracted features audio track 432
# Extracted features audio track 433
# Extracted features audio track 434
# Extracted features audio track 435
# Extracted features audio track 436
# Extracted features audio track 437
# Extracted features audio track 438
# Extracted features audio track 439
# Extracted features audio track 440
# Extracted features audio track 441
# Extracted features audio track 442
# Extracted features audio track 443
# Extracted features audio track 444
# Extracted features audio track 445
# Extracted features audio track 446
# Extracted features audio track 447
# Extracted features audio track 448
# Extracted features audio track 449
# Extracted features audio track 450
# Extracted features audio track 451
# Extracted features audio track 452
# Extracted features audio track 453
# Extracted features audio track 454
# Extracted features audio track 455
# Extracted features audio track 456
# Extracted features audio track 457
# Extracted features audio track 458
# Extracted features audio track 459
# Extracted features audio track 460
# Extracted features audio track 461
# Extracted features audio track 462
# Extracted features audio track 463
# Extracted features audio track 464
# Extracted features audio track 465
# Extracted features audio track 466
# Extracted features audio track 467
# Extracted features audio track 468
# Extracted features audio track 469
# Extracted features audio track 470
# Extracted features audio track 471
# Extracted features audio track 472
# Extracted features audio track 473
# Extracted features audio track 474
# Extracted features audio track 475
# Extracted features audio track 476
# Extracted features audio track 477
# Extracted features audio track 478
# Extracted features audio track 479
# Extracted features audio track 480
# Extracted features audio track 481
# Extracted features audio track 482
# Extracted features audio track 483
# Extracted features audio track 484
# Extracted features audio track 485
# Extracted features audio track 486
# Extracted features audio track 487
# Extracted features audio track 488
# Extracted features audio track 489
# Extracted features audio track 490
# Extracted features audio track 491
# Extracted features audio track 492
# Extracted features audio track 493
# Extracted features audio track 494
# Extracted features audio track 495
# Extracted features audio track 496
# Extracted features audio track 497
# Extracted features audio track 498
# Extracted features audio track 499
# Extracted features audio track 500
# Extracted features audio track 501
# Extracted features audio track 502
# Extracted features audio track 503
# Extracted features audio track 504
# Extracted features audio track 505
# Extracted features audio track 506
# Extracted features audio track 507
# Extracted features audio track 508
# Extracted features audio track 509
# Extracted features audio track 510
# Extracted features audio track 511
# Extracted features audio track 512
# Extracted features audio track 513
# Extracted features audio track 514
# Extracted features audio track 515
# Extracted features audio track 516
# Extracted features audio track 517
# Extracted features audio track 518
# Extracted features audio track 519
# Extracted features audio track 520
# Extracted features audio track 521
# Extracted features audio track 522
# Extracted features audio track 523
# Extracted features audio track 524
# Extracted features audio track 525
# Extracted features audio track 526
# Extracted features audio track 527
# Extracted features audio track 528
# Extracted features audio track 529
# Extracted features audio track 530
# Extracted features audio track 531
# Extracted features audio track 532
# Extracted features audio track 533
# Extracted features audio track 534
# Extracted features audio track 535
# Extracted features audio track 536
# Extracted features audio track 537
# Extracted features audio track 538
# Extracted features audio track 539
# Extracted features audio track 540
# Extracted features audio track 541
# Extracted features audio track 542
# Extracted features audio track 543
# Extracted features audio track 544
# Extracted features audio track 545
# Extracted features audio track 546
# Extracted features audio track 547
# Extracted features audio track 548
# Extracted features audio track 549
# Extracted features audio track 550
# Extracted features audio track 551
# Extracted features audio track 552
# Extracted features audio track 553
# Extracted features audio track 554
# Extracted features audio track 555
# Extracted features audio track 556
# Extracted features audio track 557
# Extracted features audio track 558
# Extracted features audio track 559
# Extracted features audio track 560
# Extracted features audio track 561
# Extracted features audio track 562
# Extracted features audio track 563
# Extracted features audio track 564
# Extracted features audio track 565
# Extracted features audio track 566
# Extracted features audio track 567
# Extracted features audio track 568
# Extracted features audio track 569
# Extracted features audio track 570
# Extracted features audio track 571
# Extracted features audio track 572
# Extracted features audio track 573
# Extracted features audio track 574
# Extracted features audio track 575
# Extracted features audio track 576
# Extracted features audio track 577
# Extracted features audio track 578
# Extracted features audio track 579
# Extracted features audio track 580
# Extracted features audio track 581
# Extracted features audio track 582
# Extracted features audio track 583
# Extracted features audio track 584
# Extracted features audio track 585
# Extracted features audio track 586
# Extracted features audio track 587
# Extracted features audio track 588
# Extracted features audio track 589
# Extracted features audio track 590
# Extracted features audio track 591
# Extracted features audio track 592
# Extracted features audio track 593
# Extracted features audio track 594
# Extracted features audio track 595
# Extracted features audio track 596
# Extracted features audio track 597
# Extracted features audio track 598
# Extracted features audio track 599
# Extracted features audio track 600
# Extracted features audio track 601
# Extracted features audio track 602
# Extracted features audio track 603
# Extracted features audio track 604
# Extracted features audio track 605
# Extracted features audio track 606
# Extracted features audio track 607
# Extracted features audio track 608
# Extracted features audio track 609
# Extracted features audio track 610
# Extracted features audio track 611
# Extracted features audio track 612
# Extracted features audio track 613
# Extracted features audio track 614
# Extracted features audio track 615
# Extracted features audio track 616
# Extracted features audio track 617
# Extracted features audio track 618
# Extracted features audio track 619
# Extracted features audio track 620
# Extracted features audio track 621
# Extracted features audio track 622
# Extracted features audio track 623
# Extracted features audio track 624
# Extracted features audio track 625
# Extracted features audio track 626
# Extracted features audio track 627
# Extracted features audio track 628
# Extracted features audio track 629
# Extracted features audio track 630
# Extracted features audio track 631
# Extracted features audio track 632
# Extracted features audio track 633
# Extracted features audio track 634
# Extracted features audio track 635
# Extracted features audio track 636
# Extracted features audio track 637
# Extracted features audio track 638
# Extracted features audio track 639
# Extracted features audio track 640
# Extracted features audio track 641
# Extracted features audio track 642
# Extracted features audio track 643
# Extracted features audio track 644
# Extracted features audio track 645
# Extracted features audio track 646
# Extracted features audio track 647
# Extracted features audio track 648
# Extracted features audio track 649
# Extracted features audio track 650
# Extracted features audio track 651
# Extracted features audio track 652
# Extracted features audio track 653
# Extracted features audio track 654
# Extracted features audio track 655
# Extracted features audio track 656
# Extracted features audio track 657
# Extracted features audio track 658
# Extracted features audio track 659
# Extracted features audio track 660
# Extracted features audio track 661
# Extracted features audio track 662
# Extracted features audio track 663
# Extracted features audio track 664
# Extracted features audio track 665
# Extracted features audio track 666
# Extracted features audio track 667
# Extracted features audio track 668
# Extracted features audio track 669
# Extracted features audio track 670
# Extracted features audio track 671
# Extracted features audio track 672
# Extracted features audio track 673
# Extracted features audio track 674
# Extracted features audio track 675
# Extracted features audio track 676
# Extracted features audio track 677
# Extracted features audio track 678
# Extracted features audio track 679
# Extracted features audio track 680
# Extracted features audio track 681
# Extracted features audio track 682
# Extracted features audio track 683
# Extracted features audio track 684
# Extracted features audio track 685
# Extracted features audio track 686
# Extracted features audio track 687
# Extracted features audio track 688
# Extracted features audio track 689
# Extracted features audio track 690
# Extracted features audio track 691
# Extracted features audio track 692
# Extracted features audio track 693
# Extracted features audio track 694
# Extracted features audio track 695
# Extracted features audio track 696
# Extracted features audio track 697
# Extracted features audio track 698
# Extracted features audio track 699
# Extracted features audio track 700
# Extracted features audio track 701
# Extracted features audio track 702
# Extracted features audio track 703
# Extracted features audio track 704
# Extracted features audio track 705
# Extracted features audio track 706
# Extracted features audio track 707
# Extracted features audio track 708
# Extracted features audio track 709
# Extracted features audio track 710
# Extracted features audio track 711
# Extracted features audio track 712
# Extracted features audio track 713
# Extracted features audio track 714
# Extracted features audio track 715
# Extracted features audio track 716
# Extracted features audio track 717
# Extracted features audio track 718
# Extracted features audio track 719
# Extracted features audio track 720
# Extracted features audio track 721
# Extracted features audio track 722
# Extracted features audio track 723
# Extracted features audio track 724
# Extracted features audio track 725
# Extracted features audio track 726
# Extracted features audio track 727
# Extracted features audio track 728
# Extracted features audio track 729
# Extracted features audio track 730
# Extracted features audio track 731
# Extracted features audio track 732
# Extracted features audio track 733
# Extracted features audio track 734
# Extracted features audio track 735
# Extracted features audio track 736
# Extracted features audio track 737
# Extracted features audio track 738
# Extracted features audio track 739
# Extracted features audio track 740
# Extracted features audio track 741
# Extracted features audio track 742
# Extracted features audio track 743
# Extracted features audio track 744
# Extracted features audio track 745
# Extracted features audio track 746
# Extracted features audio track 747
# Extracted features audio track 748
# Extracted features audio track 749
# Extracted features audio track 750
# Extracted features audio track 751
# Extracted features audio track 752
# Extracted features audio track 753
# Extracted features audio track 754
# Extracted features audio track 755
# Extracted features audio track 756
# Extracted features audio track 757
# Extracted features audio track 758
# Extracted features audio track 759
# Extracted features audio track 760
# Extracted features audio track 761
# Extracted features audio track 762
# Extracted features audio track 763
# Extracted features audio track 764
# Extracted features audio track 765
# Extracted features audio track 766
# Extracted features audio track 767
# Extracted features audio track 768
# Extracted features audio track 769
# Extracted features audio track 770
# Extracted features audio track 771
# Extracted features audio track 772
# Extracted features audio track 773
# Extracted features audio track 774
# Extracted features audio track 775
# Extracted features audio track 776
# Extracted features audio track 777
# Extracted features audio track 778
# Extracted features audio track 779
# Extracted features audio track 780
# Extracted features audio track 781
# Extracted features audio track 782
# Extracted features audio track 783
# Extracted features audio track 784
# Extracted features audio track 785
# Extracted features audio track 786
# Extracted features audio track 787
# Extracted features audio track 788
# Extracted features audio track 789
# Extracted features audio track 790
# Extracted features audio track 791
# Extracted features audio track 792
# Extracted features audio track 793
# Extracted features audio track 794
# Extracted features audio track 795
# Extracted features audio track 796
# Extracted features audio track 797
# Extracted features audio track 798

# %%
#Save as pkl
with open('mfcce_val.pkl', 'wb') as mfccf_val:
    pickle.dump(mfcce_val, mfccf_val, protocol=pickle.HIGHEST_PROTOCOL)
with open('ye_val.pkl', 'wb') as yf_val:
    pickle.dump(ys_val, yf_val, protocol=pickle.HIGHEST_PROTOCOL)

# %%
#Load Test Sets

with open("mfcce_val.pkl", 'rb') as mfcc_val:
	Xd_val = pickle.load(mfcc_val)
with open("ye_val.pkl", 'rb') as ys_val:
	yd_val = pickle.load(ys_val)

# %%
## UNCOMMENT if you already have mfcc20.pkl for test sets

# ### Load Test Sets
# with open("nameofyourmfcc20.pkl", 'rb') as mfcc_valf:
# 	mfcc_val = pickle.load(mfcc_valf)

# ### MODIFY Test Sets
# split = 10
# n = mfcc_val.shape[0]
# h = mfcc_val.shape[1]
# w = mfcc_val.shape[2]//split
# mfcce_val = np.zeros((n*split, h, w))
# for i in range(split):
#     mfcce_val[i*n:(i+1)*n, :, :w] = mfcc_val[:,:,i*w:(i+1)*w]
# Xd_val = mfcce_val

# %%
# Model for training and validation

tf.reset_default_graph()

n_input = 20 * 249 
n_classs = 8 
image_height = 20
image_width = 249
# convolutional layer property
conv_size = 3
n_filter1 = 32
n_filter2 = 64
n_filter3 = 128
# pooling layer property
pool_size = 2
# fully-connected layer property
fc_dim = 512

# Placeholder and variables
# TODO : declare placeholder and variables

X = tf.placeholder(tf.float32, [None, image_height, image_width])
y = tf.placeholder(tf.int64, [None, n_classs])
is_training = tf.placeholder(tf.bool)

# Build model
# TODO : build your model here
# Model

def model(X,y,is_training):
    regularizer = tf.contrib.layers.l2_regularizer(1e-4)
    activation = tf.nn.relu
    init = tf.contrib.layers.xavier_initializer()
    
    w_fc = tf.get_variable("W_fc", shape=[8*n_filter3, fc_dim])
    b_fc = tf.get_variable("b_fc", shape=[fc_dim])
    w_out = tf.get_variable("W_out", shape=[fc_dim, n_classs])
    b_out = tf.get_variable("b_out", shape=[n_classs])
    
    x_reshaped = tf.reshape(X, [-1, image_height, image_width, 1])
    c11 = tf.layers.conv2d(x_reshaped, n_filter1, conv_size, 1, "same", activation = activation, kernel_initializer = init, kernel_regularizer = regularizer)
    c12 = tf.layers.conv2d(c11, n_filter1, conv_size, 1, "same", activation = activation, kernel_initializer = init, kernel_regularizer = regularizer)
    mp1 = tf.layers.max_pooling2d(c12, pool_size, 2,  "same")
    c21 = tf.layers.conv2d(mp1, n_filter1, conv_size, 1, "same", activation = activation, kernel_initializer = init, kernel_regularizer = regularizer)
    c22 = tf.layers.conv2d(c21, n_filter1, conv_size, 1, "same", activation = activation, kernel_initializer = init, kernel_regularizer = regularizer)
    mp2 = tf.layers.max_pooling2d(c22, pool_size, 2,  "same")
    c31 = tf.layers.conv2d(mp2, n_filter2, conv_size, 1, "same", activation = activation, kernel_initializer = init, kernel_regularizer = regularizer)
    c32 = tf.layers.conv2d(c31, n_filter2, conv_size, 1, "same", activation = activation, kernel_initializer = init, kernel_regularizer = regularizer)
    mp3 = tf.layers.max_pooling2d(c32, pool_size, 2,  "same")
    c41 = tf.layers.conv2d(mp3, n_filter2, conv_size, 1, "same", activation = activation, kernel_initializer = init, kernel_regularizer = regularizer)
    c42 = tf.layers.conv2d(c41, n_filter2, conv_size, 1, "same", activation = activation, kernel_initializer = init, kernel_regularizer = regularizer)
    mp4 = tf.layers.max_pooling2d(c42, pool_size, 2, "same")
    c51 = tf.layers.conv2d(mp4, n_filter3, conv_size, 1, "same", activation = activation, kernel_initializer = init, kernel_regularizer = regularizer)
    c52 = tf.layers.conv2d(c51, n_filter3, conv_size, 1, "same", activation = activation, kernel_initializer = init, kernel_regularizer = regularizer)
    mp5 = tf.layers.max_pooling2d(c52, pool_size, 2, "same")
    if is_training is not None:
        mp5 = tf.nn.dropout(mp5, 0.5)    
    flat = tf.reshape(mp5, [-1, 8*n_filter3])
    fc = tf.nn.relu(tf.matmul(flat, w_fc) + b_fc)
    y_out = tf.matmul(fc, w_out) + b_out
    return y_out

y_out = model(X,y,is_training)

# Loss and optimizer
# TODO : declare loss and optimizer operation

total_loss = tf.losses.softmax_cross_entropy(y,logits=y_out) 
mean_loss = tf.reduce_mean(total_loss)
optimizer = tf.train.AdamOptimizer(1e-4) 
extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
with tf.control_dependencies(extra_update_ops):
    train_step = optimizer.minimize(mean_loss)    
correct_prediction = tf.equal(tf.argmax(y_out,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
# properties
# General
# TODO : declare additional properties
# not fixed (change or add property as you like)
batch_size = 5
epoch_num = 5
print_every = 10

# fixed
metadata_path = 'dataset/track_metadata.csv'
# True if you want to train, False if you already trained your model
# TODO : IMPORTANT !!! Please change it to False when you submit your code
is_train_mode = False
validation = True
# TODO : IMPORTANT !!! Please specify the path where your best model is saved
# example : checkpoint/run-0925-0348
checkpoint_path = 'checkpoint/cnn'
# 'track_genre_top' for project 1, 'listens' for project 2
label_column_name = 'track_genre_top'

# X, y, mean_loss,correct_prediction,train_step, accuracy = my_model(lr = 2e-4, rl = 1e-4,  is_training= is_train_mode)
#load data

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    saver = tf.train.Saver()
    saver.restore(sess, checkpoint_path)			
    if is_train_mode:
        variables = [mean_loss,correct_prediction,train_step]
        train_indicies = np.arange(Xd.shape[0])
        np.random.shuffle(train_indicies)
        iter_cnt = 0
        for e in range(epoch_num):
            correct = 0
            losses = []
            for i in range(int(math.ceil(Xd.shape[0]/batch_size))):
                start_idx = (i*batch_size)%Xd.shape[0]
                idx = train_indicies[start_idx:start_idx+batch_size]
                feed_dict = {X: Xd[idx,:],
                             y: yd[idx] }
                actual_batch_size = yd[idx].shape[0]
                loss, corr, _ = sess.run(variables,feed_dict=feed_dict)
                losses.append(loss*actual_batch_size)
                correct += np.sum(corr)
                if is_train_mode and (iter_cnt % print_every) == 0:
                    print("Iteration {0}: with minibatch training loss = {1:.3g} and accuracy of {2:.2g}"\
                          .format(iter_cnt,loss,np.sum(corr)/actual_batch_size))
                iter_cnt += 1
            total_correct = correct/Xd.shape[0]
            total_loss = np.sum(losses)/Xd.shape[0]
            print("Epoch {2}, Overall loss = {0:.3g} and accuracy of {1:.3g}"\
              .format(total_loss,total_correct,e+1))
            plt.plot(losses)
            plt.grid(True)
            plt.title('Epoch {} Loss'.format(e+1))
            plt.xlabel('minibatch number')
            plt.ylabel('minibatch loss')
            plt.show()
        print('Training finished !')
#         output_dir = checkpoint_path + '/run-%02d%02d-%02d%02d' % tuple(localtime(time()))[1:5]
        output_dir = checkpoint_path
        if not gfile.Exists(output_dir):
            gfile.MakeDirs(output_dir)
        saver.save(sess, output_dir)
        print('Model saved in file : %s' % output_dir)

    if validation:
        correct = 0
        losses = []
        preds = np.zeros([1,8])
        train_indicies = np.arange(Xd_val.shape[0])
        variables = [mean_loss,correct_prediction,y_out]
        for j in range(int(math.ceil(Xd_val.shape[0]/batch_size))):
            start_idx = (j*batch_size)%Xd_val.shape[0]
            idx = train_indicies[start_idx:start_idx+batch_size]
            feed_dict_val = {X: Xd_val[idx, :],
                         y: yd_val[idx] }
            actual_batch_size = yd_val[idx].shape[0]
            loss, corr, predict = sess.run(variables,feed_dict=feed_dict_val)
            preds = np.concatenate((preds, predict), axis = 0)
            losses.append(loss*actual_batch_size)
            correct += np.sum(corr)
        votes = np.zeros([Xd_val.shape[0]//10, 8])
        for n, i in enumerate(preds[1:]):
            votes[n%(Xd_val.shape[0]//10),np.argmax(i)] += 1
        total_val_correct = correct/Xd_val.shape[0]
        total_val_loss = np.sum(losses)/Xd_val.shape[0]
        sum_total_val_correct = sum(((np.argmax(votes, axis = 1) == np.argmax(yd_val[:Xd_val.shape[0]//10], axis = 1))))/(Xd_val.shape[0]//10)
        print("Validation loss, Overall loss = {0:.3g}, accuracy of {1:.3g}"\
          .format(total_val_loss,sum_total_val_correct))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoint/cnn
# Validation loss, Overall loss = 3.84, accuracy of 0.513
